# %% [markdown]
# # Imports

# %%
import json
import airr
from make_jobs import create_vdjpipe_job_files
from make_jobs import create_igblast_job_file
from make_jobs import create_repcalc_job_file

# %% [markdown]
# # Data

# %%
# VDJ Pipe
project_id='4661bdd7-7498-412d-b218-f42044550b96'
data = airr.read_airr('./repertoires.airr.json')

# %% [markdown]
# # IgBlast

# %%
# job_uuid_dict = {
#     'library_33' : '37afeb5b-ae5c-49a1-8c75-366f978c996a/9251db8a-f7ec-45a6-8f3b-79f25232154c-007',
#     'library_34' : '91ca4180-37bd-4d93-aa7b-4425deee0b95/6c3d5355-4429-4431-be5b-51162af8b849-007'
# }

# # job_uuid_dict = {
# #     'library_34' : '91ca4180-37bd-4d93-aa7b-4425deee0b95/6c3d5355-4429-4431-be5b-51162af8b849-007'
# # }

# '''
# project file location
# library 33
# /projects/4661bdd7-7498-412d-b218-f42044550b96/analyses/37afeb5b-ae5c-49a1-8c75-366f978c996a/9251db8a-f7ec-45a6-8f3b-79f25232154c-007

# library 34
# #/projects/4661bdd7-7498-412d-b218-f42044550b96/analyses/91ca4180-37bd-4d93-aa7b-4425deee0b95/6c3d5355-4429-4431-be5b-51162af8b849-007


# '''

# igblast_job = create_igblast_job_file(data, project_id, job_uuid_dict, 'KidneyTCR')

# %% [markdown]
# # Repcalc

# %%
job_id = ['0c31b9fc-9732-4eb0-acf9-67b015a0e12d-007', 'edfebb12-dd91-4a75-9827-338f6fee9f5c/1361103b-f356-4833-93ae-2a50cfd608c1-007']# IgBLAST job uuid

repcalc_job = create_repcalc_job_file(data, project_id, job_id, 'KidneyTCR')
